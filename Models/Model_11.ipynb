# %%
import pandas as pd
import numpy as np
from tqdm import tqdm
import copy
import sklearn

import os
import pandas as pd
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, AdaBoostClassifier
from sklearn.model_selection import StratifiedKFold, RandomizedSearchCV
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split
from scipy.stats import uniform as sp_randFloat
from scipy.stats import randint as sp_randInt
from sklearn import preprocessing
from sklearn import metrics
import numpy as np
import pandas as pd
from time import time
import pprint
import joblib
from xgboost.sklearn import XGBClassifier 
import numpy as np
from xgboost import XGBClassifier
from bayes_opt import BayesianOptimization
from sklearn.model_selection import cross_val_score

import warnings
warnings.filterwarnings("ignore")

# Classifiers
from catboost import CatBoostClassifier

# Model selection
from sklearn.model_selection import StratifiedKFold

# Metrics
from sklearn.metrics import roc_auc_score
from sklearn.metrics import make_scorer

# Skopt functions
from skopt import BayesSearchCV
from skopt.callbacks import DeadlineStopper, VerboseCallback, DeltaXStopper
from skopt.space import Real, Categorical, Integer
from time import time

# %%
train_ = pd.read_csv('Train.csv')
test_ = pd.read_csv('Test.csv')
submission_ = pd.read_csv('SampleSubmission.csv')

# %%
from sklearn.model_selection import KFold
fold_train = []
kf = KFold(n_splits=5, shuffle=False)
for r, (train_index, test_index) in enumerate(kf.split(train_)):
    test = train_.iloc[test_index]

    X_test = []
    X_test_columns = test.columns
    for v in test.values:
        info = v[:8]
        binary = v[8:]
        index = [k for k, i in enumerate(binary) if i == 1]
        for i in index:
            for k in range(len(binary)):
                if k == i:
                    binary_transformed = list(copy.copy(binary))
                    binary_transformed[i] = 0
                    X_test.append(list(info) + binary_transformed + [8+k])

    X_test = pd.DataFrame(X_test)
    X_test.columns = ['ID', 'join_date', 'sex', 'marital_status', 'birth_year', 'branch_code',
          'occupation_code', 'occupation_category_code', 'P5DA', 'RIBP', '8NN1',
          '7POT', '66FJ', 'GYSR', 'SOP4', 'RVSZ', 'PYUQ', 'LJR9', 'N2MW', 'AHXO',
          'BSTQ', 'FM3X', 'K6QO', 'QBOL', 'JWFN', 'JZ9D', 'J9JW', 'GHYX', 'ECY3', 'product_num']

    X_test['ID'] = [str(r)+'_'+str(i) for i in range(X_test.shape[0])]

    test = []
    test_columns = X_test.columns

    for v in X_test.values:
        info = v[:8]
        binary = v[8:-1]
        num = v[-1]
        index = [k for k, i in enumerate(binary) if i == 1]
        for k in range(len(binary)):
            if k not in index:
                if 8+k == num:
                    test.append(list(info) + list(binary) + [test_columns[8+k]] + [1])
                else:
                    test.append(list(info) + list(binary) + [test_columns[8+k]] + [0])
    test = pd.DataFrame(test)
    test.columns = ['ID', 'join_date', 'sex', 'marital_status', 'birth_year', 'branch_code',
        'occupation_code', 'occupation_category_code', 'P5DA', 'RIBP', '8NN1',
        '7POT', '66FJ', 'GYSR', 'SOP4', 'RVSZ', 'PYUQ', 'LJR9', 'N2MW', 'AHXO',
        'BSTQ', 'FM3X', 'K6QO', 'QBOL', 'JWFN', 'JZ9D', 'J9JW', 'GHYX', 'ECY3', 'product_pred', 'target']

    test = test[['ID', 'product_pred', 'target']]
    test['ID X PCODE'] = test['ID'] + ' X ' + test['product_pred']
    del test['ID'], test['product_pred']
    test.columns = ['Label', 'ID X PCODE']

    submit1 = pd.read_csv('0_fold' + str(r) + '.csv')
    submit2 = pd.read_csv('1_fold' + str(r) + '.csv')
    submit3 = pd.read_csv('2_fold' + str(r) + '.csv')

    test = test.merge(submit1, how='left', on='ID X PCODE')
    test = test.merge(submit2, how='left', on='ID X PCODE')
    test = test.merge(submit3, how='left', on='ID X PCODE')

    test.columns = ['target', 'ID X PCODE', 'Label1', 'Label2', 'Label3']

    fold_train.append(test)

fold_train = pd.concat(fold_train)

# %%
test = []
test_columns = test_.columns

for v in test_.values:
    info = v[:8]
    binary = v[8:]
    index = [k for k, i in enumerate(binary) if i == 1]
    for k in range(len(binary)):
        if k not in index:
            test.append(list(info) + list(binary) + [test_columns[8+k]])
test = pd.DataFrame(test)
test.columns = ['ID', 'join_date', 'sex', 'marital_status', 'birth_year', 'branch_code',
        'occupation_code', 'occupation_category_code', 'P5DA', 'RIBP', '8NN1',
        '7POT', '66FJ', 'GYSR', 'SOP4', 'RVSZ', 'PYUQ', 'LJR9', 'N2MW', 'AHXO',
        'BSTQ', 'FM3X', 'K6QO', 'QBOL', 'JWFN', 'JZ9D', 'J9JW', 'GHYX', 'ECY3', 'product_pred',]

test = test[['ID', 'product_pred']]
test['ID X PCODE'] = test['ID'] + ' X ' + test['product_pred']
del test['ID'], test['product_pred']

submit1 = pd.read_csv('0_main.csv')
submit2 = pd.read_csv('1_main.csv')
submit3 = pd.read_csv('2_main.csv')

test = test.merge(submit1, how='left', on='ID X PCODE')
test = test.merge(submit2, how='left', on='ID X PCODE')
test = test.merge(submit3, how='left', on='ID X PCODE')

test.columns = ['ID X PCODE', 'Label1', 'Label2', 'Label3']

# %%
test.head()
# Out:
#        ID X PCODE    Label1    Label2    Label3
# 0  F86J5PC X P5DA  0.000003  0.000915  0.005931
# 1  F86J5PC X RIBP  0.000655  0.000955  0.003241
# 2  F86J5PC X 8NN1  0.000007  0.000915  0.005931
# 3  F86J5PC X 7POT  0.000062  0.000915  0.005931
# 4  F86J5PC X 66FJ  0.000229  0.000915  0.005931

# %%
from catboost import CatBoostClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier

models = []
# models.append(LGBMClassifier(random_state=17, num_trees=300, max_depth = 3))
# models.append(LGBMClassifier(random_state=17, num_trees=500, max_depth = 5))
models.append(XGBClassifier(learning_rate=0.1675, max_depth=10, gamma=1.976, n_estimators=550))
models.append(XGBClassifier(learning_rate=0.1, max_depth=20, gamma=1.576, n_estimators=750))
models.append(CatBoostClassifier(random_state=17, num_trees=500, max_depth=3))
# models.append(CatBoostClassifier(random_state=17, num_trees=1000, max_depth=5))

# %%
for i in range(len(models)):
    models[i].fit(fold_train.drop(columns=['target', 'ID X PCODE']), fold_train['target'])
# Out:
# Learning rate set to 0.415293
# 0:	learn: 0.1173410	total: 259ms	remaining: 2m 9s
# 1:	learn: 0.0654411	total: 435ms	remaining: 1m 48s
# 2:	learn: 0.0395398	total: 593ms	remaining: 1m 38s
# 3:	learn: 0.0364164	total: 755ms	remaining: 1m 33s
# 4:	learn: 0.0345066	total: 903ms	remaining: 1m 29s
# 5:	learn: 0.0343755	total: 1.04s	remaining: 1m 25s
# 50:	learn: 0.0320772	total: 8.68s	remaining: 1m 16s
# 51:	learn: 0.0320712	total: 8.88s	remaining: 1m 16s
# 52:	learn: 0.0320682	total: 9.09s	remaining: 1m 16s
# 53:	learn: 0.0320665	total: 9.24s	remaining: 1m 16s
# 54:	learn: 0.0320638	total: 9.42s	remaining: 1m 16s
# 55:	learn: 0.0320624	total: 9.55s	remaining: 1m 15s
# 56:	learn: 0.0320570	total: 9.7s	remaining: 1m 15s
# 57:	learn: 0.0320534	total: 9.9s	remaining: 1m 15s
# 58:	learn: 0.0320451	total: 10.1s	remaining: 1m 15s
# 59:	learn: 0.0320428	total: 10.3s	remaining: 1m 15s
# 60:	learn: 0.0320393	total: 10.4s	remaining: 1m 14s
# 61:	learn: 0.0320365	total: 10.6s	remaining: 1m 15s
# 62:	learn: 0.0320346	total: 10.8s	remaining: 1m 14s
# 63:	learn: 0.0320319	total: 10.9s	remaining: 1m 14s
# 64:	learn: 0.0320276	total: 11.1s	remaining: 1m 14s
# 65:	learn: 0.0320254	total: 11.3s	remaining: 1m 14s
# 66:	learn: 0.0320240	total: 11.5s	remaining: 1m 14s
# 67:	learn: 0.0320221	total: 11.7s	remaining: 1m 14s
# 68:	learn: 0.0320183	total: 11.8s	remaining: 1m 13s
# 69:	learn: 0.0320165	total: 12.1s	remaining: 1m 14s
# 70:	learn: 0.0320156	total: 12.2s	remaining: 1m 13s
# 71:	learn: 0.0320152	total: 12.4s	remaining: 1m 13s
# 72:	learn: 0.0320134	total: 12.6s	remaining: 1m 13s
# 73:	learn: 0.0320105	total: 12.8s	remaining: 1m 13s
# 74:	learn: 0.0320081	total: 12.9s	remaining: 1m 13s
# 75:	learn: 0.0320060	total: 13.1s	remaining: 1m 13s
# 76:	learn: 0.0320046	total: 13.3s	remaining: 1m 13s
# 77:	learn: 0.0320031	total: 13.5s	remaining: 1m 12s
# 78:	learn: 0.0320014	total: 13.7s	remaining: 1m 12s
# 79:	learn: 0.0319985	total: 13.8s	remaining: 1m 12s
# 80:	learn: 0.0319833	total: 14s	remaining: 1m 12s
# 81:	learn: 0.0319811	total: 14.2s	remaining: 1m 12s
# 82:	learn: 0.0319788	total: 14.4s	remaining: 1m 12s
# 83:	learn: 0.0319788	total: 14.5s	remaining: 1m 11s
# 84:	learn: 0.0319753	total: 14.7s	remaining: 1m 11s
# 85:	learn: 0.0319718	total: 14.9s	remaining: 1m 11s
# 86:	learn: 0.0319704	total: 15s	remaining: 1m 11s
# 87:	learn: 0.0319681	total: 15.3s	remaining: 1m 11s
# 88:	learn: 0.0319671	total: 15.4s	remaining: 1m 11s
# 89:	learn: 0.0319659	total: 15.5s	remaining: 1m 10s
# 90:	learn: 0.0319653	total: 15.7s	remaining: 1m 10s
# 91:	learn: 0.0319639	total: 15.8s	remaining: 1m 10s
# 92:	learn: 0.0319621	total: 16.1s	remaining: 1m 10s
# 93:	learn: 0.0319588	total: 16.2s	remaining: 1m 9s
# 94:	learn: 0.0319571	total: 16.3s	remaining: 1m 9s
# 280:	learn: 0.0318858	total: 42s	remaining: 32.7s
# 281:	learn: 0.0318858	total: 42.1s	remaining: 32.5s
# 282:	learn: 0.0318858	total: 42.2s	remaining: 32.4s
# 283:	learn: 0.0318858	total: 42.3s	remaining: 32.2s
# 284:	learn: 0.0318858	total: 42.5s	remaining: 32s
# 285:	learn: 0.0318858	total: 42.6s	remaining: 31.9s
# 286:	learn: 0.0318858	total: 42.7s	remaining: 31.7s
# 287:	learn: 0.0318858	total: 42.8s	remaining: 31.5s
# 288:	learn: 0.0318858	total: 42.9s	remaining: 31.3s
# 289:	learn: 0.0318858	total: 43s	remaining: 31.2s
# 290:	learn: 0.0318858	total: 43.2s	remaining: 31s
# 291:	learn: 0.0318858	total: 43.3s	remaining: 30.8s
# 292:	learn: 0.0318858	total: 43.4s	remaining: 30.7s
# 293:	learn: 0.0318858	total: 43.5s	remaining: 30.5s
# 294:	learn: 0.0318858	total: 43.6s	remaining: 30.3s
# 295:	learn: 0.0318858	total: 43.8s	remaining: 30.2s
# 296:	learn: 0.0318858	total: 43.9s	remaining: 30s
# 297:	learn: 0.0318858	total: 44s	remaining: 29.8s
# 298:	learn: 0.0318858	total: 44.1s	remaining: 29.7s
# 299:	learn: 0.0318858	total: 44.3s	remaining: 29.5s
# 300:	learn: 0.0318858	total: 44.4s	remaining: 29.3s
# 301:	learn: 0.0318858	total: 44.5s	remaining: 29.2s
# 302:	learn: 0.0318858	total: 44.6s	remaining: 29s
# 303:	learn: 0.0318858	total: 44.8s	remaining: 28.9s
# 304:	learn: 0.0318858	total: 44.9s	remaining: 28.7s
# 305:	learn: 0.0318858	total: 45s	remaining: 28.5s
# 306:	learn: 0.0318858	total: 45.1s	remaining: 28.4s
# 307:	learn: 0.0318858	total: 45.2s	remaining: 28.2s
# 308:	learn: 0.0318858	total: 45.3s	remaining: 28s
# 309:	learn: 0.0318858	total: 45.4s	remaining: 27.8s
# 310:	learn: 0.0318858	total: 45.6s	remaining: 27.7s
# 311:	learn: 0.0318858	total: 45.7s	remaining: 27.5s
# 312:	learn: 0.0318858	total: 45.8s	remaining: 27.4s
# 313:	learn: 0.0318858	total: 45.9s	remaining: 27.2s
# 314:	learn: 0.0318858	total: 46.1s	remaining: 27s
# 315:	learn: 0.0318858	total: 46.2s	remaining: 26.9s
# 316:	learn: 0.0318858	total: 46.3s	remaining: 26.7s
# 317:	learn: 0.0318858	total: 46.4s	remaining: 26.6s
# 318:	learn: 0.0318858	total: 46.6s	remaining: 26.4s
# 319:	learn: 0.0318858	total: 46.6s	remaining: 26.2s
# 320:	learn: 0.0318858	total: 46.8s	remaining: 26.1s
# 321:	learn: 0.0318858	total: 46.9s	remaining: 25.9s
# 322:	learn: 0.0318858	total: 47.1s	remaining: 25.8s
# 323:	learn: 0.0318858	total: 47.2s	remaining: 25.6s
# 324:	learn: 0.0318858	total: 47.3s	remaining: 25.5s
# 325:	learn: 0.0318858	total: 47.4s	remaining: 25.3s
# 326:	learn: 0.0318858	total: 47.5s	remaining: 25.1s
# 327:	learn: 0.0318858	total: 47.6s	remaining: 25s
# 328:	learn: 0.0318858	total: 47.8s	remaining: 24.8s
# 329:	learn: 0.0318858	total: 47.9s	remaining: 24.7s
# 330:	learn: 0.0318858	total: 48.1s	remaining: 24.5s
# 331:	learn: 0.0318858	total: 48.2s	remaining: 24.4s
# 332:	learn: 0.0318858	total: 48.3s	remaining: 24.2s
# 333:	learn: 0.0318837	total: 48.5s	remaining: 24.1s
# 334:	learn: 0.0318799	total: 48.6s	remaining: 23.9s
# 335:	learn: 0.0318782	total: 48.8s	remaining: 23.8s
# 336:	learn: 0.0318772	total: 48.9s	remaining: 23.7s
# 337:	learn: 0.0318760	total: 49.1s	remaining: 23.5s
# 338:	learn: 0.0318749	total: 49.2s	remaining: 23.4s
# 339:	learn: 0.0318739	total: 49.4s	remaining: 23.3s
# 340:	learn: 0.0318724	total: 49.5s	remaining: 23.1s
# 341:	learn: 0.0318708	total: 49.7s	remaining: 23s
# 342:	learn: 0.0318707	total: 49.9s	remaining: 22.8s
# 343:	learn: 0.0318695	total: 50s	remaining: 22.7s
# 344:	learn: 0.0318670	total: 50.2s	remaining: 22.5s
# 345:	learn: 0.0318655	total: 50.3s	remaining: 22.4s
# 346:	learn: 0.0318635	total: 50.5s	remaining: 22.3s
# 347:	learn: 0.0318626	total: 50.7s	remaining: 22.1s
# 348:	learn: 0.0318611	total: 50.8s	remaining: 22s
# 349:	learn: 0.0318590	total: 51s	remaining: 21.8s
# 350:	learn: 0.0318443	total: 51.1s	remaining: 21.7s
# 351:	learn: 0.0318422	total: 51.3s	remaining: 21.6s
# 352:	learn: 0.0318402	total: 51.4s	remaining: 21.4s
# 353:	learn: 0.0318402	total: 51.5s	remaining: 21.3s
# 354:	learn: 0.0318402	total: 51.7s	remaining: 21.1s
# 355:	learn: 0.0318402	total: 51.8s	remaining: 20.9s
# 356:	learn: 0.0318402	total: 51.9s	remaining: 20.8s
# 357:	learn: 0.0318402	total: 52s	remaining: 20.6s
# 358:	learn: 0.0318402	total: 52.2s	remaining: 20.5s
# 359:	learn: 0.0318402	total: 52.3s	remaining: 20.3s
# 360:	learn: 0.0318402	total: 52.4s	remaining: 20.2s
# 361:	learn: 0.0318402	total: 52.5s	remaining: 20s
# 362:	learn: 0.0318402	total: 52.7s	remaining: 19.9s
# 363:	learn: 0.0318362	total: 52.8s	remaining: 19.7s
# 364:	learn: 0.0318353	total: 53s	remaining: 19.6s
# 365:	learn: 0.0318331	total: 53.2s	remaining: 19.5s
# 366:	learn: 0.0318320	total: 53.4s	remaining: 19.3s
# 367:	learn: 0.0318312	total: 53.5s	remaining: 19.2s
# 368:	learn: 0.0318301	total: 53.6s	remaining: 19s
# 369:	learn: 0.0318277	total: 53.8s	remaining: 18.9s
# 370:	learn: 0.0318270	total: 53.9s	remaining: 18.7s
# 371:	learn: 0.0318261	total: 54.1s	remaining: 18.6s
# 372:	learn: 0.0318215	total: 54.2s	remaining: 18.5s
# 373:	learn: 0.0318181	total: 54.4s	remaining: 18.3s
# 374:	learn: 0.0318152	total: 54.5s	remaining: 18.2s
# 375:	learn: 0.0318143	total: 54.7s	remaining: 18s
# 376:	learn: 0.0318132	total: 54.9s	remaining: 17.9s
# 377:	learn: 0.0318113	total: 55s	remaining: 17.8s
# 378:	learn: 0.0318087	total: 55.2s	remaining: 17.6s
# 379:	learn: 0.0318065	total: 55.4s	remaining: 17.5s
# 380:	learn: 0.0318048	total: 55.5s	remaining: 17.3s
# 381:	learn: 0.0318028	total: 55.7s	remaining: 17.2s
# 382:	learn: 0.0318016	total: 55.9s	remaining: 17.1s
# 383:	learn: 0.0318007	total: 56s	remaining: 16.9s
# 384:	learn: 0.0317999	total: 56.2s	remaining: 16.8s
# 385:	learn: 0.0317977	total: 56.4s	remaining: 16.6s
# 386:	learn: 0.0317966	total: 56.5s	remaining: 16.5s
# 387:	learn: 0.0317949	total: 56.7s	remaining: 16.4s
# 388:	learn: 0.0317925	total: 56.8s	remaining: 16.2s
# 389:	learn: 0.0317899	total: 57s	remaining: 16.1s
# 390:	learn: 0.0317877	total: 57.1s	remaining: 15.9s
# 391:	learn: 0.0317845	total: 57.3s	remaining: 15.8s
# 392:	learn: 0.0317836	total: 57.5s	remaining: 15.6s
# 393:	learn: 0.0317816	total: 57.6s	remaining: 15.5s
# 394:	learn: 0.0317801	total: 57.8s	remaining: 15.4s
# 395:	learn: 0.0317792	total: 58s	remaining: 15.2s
# 396:	learn: 0.0317779	total: 58.1s	remaining: 15.1s
# 397:	learn: 0.0317761	total: 58.3s	remaining: 14.9s
# 398:	learn: 0.0317727	total: 58.5s	remaining: 14.8s
# 399:	learn: 0.0317715	total: 58.6s	remaining: 14.7s
# 400:	learn: 0.0317715	total: 58.8s	remaining: 14.5s
# 401:	learn: 0.0317707	total: 59s	remaining: 14.4s
# 402:	learn: 0.0317695	total: 59.2s	remaining: 14.2s
# 403:	learn: 0.0317688	total: 59.3s	remaining: 14.1s
# 404:	learn: 0.0317661	total: 59.5s	remaining: 14s
# 405:	learn: 0.0317661	total: 59.7s	remaining: 13.8s
# 406:	learn: 0.0317661	total: 59.8s	remaining: 13.7s
# 407:	learn: 0.0317661	total: 59.9s	remaining: 13.5s
# 408:	learn: 0.0317661	total: 1m	remaining: 13.4s
# 409:	learn: 0.0317661	total: 1m	remaining: 13.2s
# 410:	learn: 0.0317661	total: 1m	remaining: 13.1s
# 411:	learn: 0.0317661	total: 1m	remaining: 12.9s
# 412:	learn: 0.0317661	total: 1m	remaining: 12.8s
# 413:	learn: 0.0317661	total: 1m	remaining: 12.6s
# 414:	learn: 0.0317661	total: 1m	remaining: 12.5s
# 415:	learn: 0.0317661	total: 1m	remaining: 12.3s
# 416:	learn: 0.0317661	total: 1m 1s	remaining: 12.2s
# 417:	learn: 0.0317661	total: 1m 1s	remaining: 12s
# 418:	learn: 0.0317661	total: 1m 1s	remaining: 11.9s
# 419:	learn: 0.0317661	total: 1m 1s	remaining: 11.7s
# 420:	learn: 0.0317661	total: 1m 1s	remaining: 11.6s
# 421:	learn: 0.0317660	total: 1m 1s	remaining: 11.4s
# 422:	learn: 0.0317626	total: 1m 1s	remaining: 11.3s
# 423:	learn: 0.0317602	total: 1m 2s	remaining: 11.1s
# 424:	learn: 0.0317588	total: 1m 2s	remaining: 11s
# 425:	learn: 0.0317580	total: 1m 2s	remaining: 10.8s
# 426:	learn: 0.0317542	total: 1m 2s	remaining: 10.7s
# 427:	learn: 0.0317527	total: 1m 2s	remaining: 10.5s
# 428:	learn: 0.0317527	total: 1m 2s	remaining: 10.4s
# 429:	learn: 0.0317527	total: 1m 2s	remaining: 10.2s
# 430:	learn: 0.0317522	total: 1m 3s	remaining: 10.1s
# 431:	learn: 0.0317513	total: 1m 3s	remaining: 9.94s
# 432:	learn: 0.0317495	total: 1m 3s	remaining: 9.8s
# 433:	learn: 0.0317483	total: 1m 3s	remaining: 9.66s
# 434:	learn: 0.0317483	total: 1m 3s	remaining: 9.51s
# 435:	learn: 0.0317475	total: 1m 3s	remaining: 9.37s
# 436:	learn: 0.0317433	total: 1m 3s	remaining: 9.22s
# 437:	learn: 0.0317425	total: 1m 4s	remaining: 9.07s
# 438:	learn: 0.0317419	total: 1m 4s	remaining: 8.93s
# 439:	learn: 0.0317412	total: 1m 4s	remaining: 8.78s
# 440:	learn: 0.0317395	total: 1m 4s	remaining: 8.64s
# 441:	learn: 0.0317390	total: 1m 4s	remaining: 8.49s
# 442:	learn: 0.0317374	total: 1m 4s	remaining: 8.35s
# 443:	learn: 0.0317368	total: 1m 4s	remaining: 8.2s
# 444:	learn: 0.0317361	total: 1m 5s	remaining: 8.05s
# 445:	learn: 0.0317355	total: 1m 5s	remaining: 7.91s
# 446:	learn: 0.0317344	total: 1m 5s	remaining: 7.76s
# 447:	learn: 0.0317326	total: 1m 5s	remaining: 7.62s
# 448:	learn: 0.0317320	total: 1m 5s	remaining: 7.48s
# 449:	learn: 0.0317314	total: 1m 6s	remaining: 7.33s
# 450:	learn: 0.0317301	total: 1m 6s	remaining: 7.19s
# 451:	learn: 0.0317301	total: 1m 6s	remaining: 7.04s
# 452:	learn: 0.0317301	total: 1m 6s	remaining: 6.89s
# 453:	learn: 0.0317301	total: 1m 6s	remaining: 6.74s
# 454:	learn: 0.0317301	total: 1m 6s	remaining: 6.59s
# 455:	learn: 0.0317301	total: 1m 6s	remaining: 6.44s
# 456:	learn: 0.0317301	total: 1m 6s	remaining: 6.3s
# 457:	learn: 0.0317301	total: 1m 7s	remaining: 6.15s
# 458:	learn: 0.0317301	total: 1m 7s	remaining: 6s
# 459:	learn: 0.0317301	total: 1m 7s	remaining: 5.85s
# 460:	learn: 0.0317301	total: 1m 7s	remaining: 5.7s
# 461:	learn: 0.0317301	total: 1m 7s	remaining: 5.55s
# 462:	learn: 0.0317301	total: 1m 7s	remaining: 5.41s
# 463:	learn: 0.0317301	total: 1m 7s	remaining: 5.26s
# 464:	learn: 0.0317301	total: 1m 7s	remaining: 5.11s
# 465:	learn: 0.0317301	total: 1m 8s	remaining: 4.96s
# 466:	learn: 0.0317301	total: 1m 8s	remaining: 4.82s
# 467:	learn: 0.0317301	total: 1m 8s	remaining: 4.67s
# 468:	learn: 0.0317301	total: 1m 8s	remaining: 4.52s
# 469:	learn: 0.0317301	total: 1m 8s	remaining: 4.37s
# 470:	learn: 0.0317301	total: 1m 8s	remaining: 4.23s
# 471:	learn: 0.0317301	total: 1m 8s	remaining: 4.08s
# 472:	learn: 0.0317298	total: 1m 8s	remaining: 3.93s
# 473:	learn: 0.0317289	total: 1m 9s	remaining: 3.79s
# 474:	learn: 0.0317281	total: 1m 9s	remaining: 3.64s
# 475:	learn: 0.0317273	total: 1m 9s	remaining: 3.5s
# 476:	learn: 0.0317255	total: 1m 9s	remaining: 3.35s
# 477:	learn: 0.0317250	total: 1m 9s	remaining: 3.21s
# 478:	learn: 0.0317250	total: 1m 9s	remaining: 3.06s
# 479:	learn: 0.0317240	total: 1m 10s	remaining: 2.92s
# 480:	learn: 0.0317231	total: 1m 10s	remaining: 2.77s
# 481:	learn: 0.0317225	total: 1m 10s	remaining: 2.63s
# 482:	learn: 0.0317225	total: 1m 10s	remaining: 2.48s
# 483:	learn: 0.0317215	total: 1m 10s	remaining: 2.34s
# 484:	learn: 0.0317211	total: 1m 10s	remaining: 2.19s
# 485:	learn: 0.0317201	total: 1m 11s	remaining: 2.05s
# 486:	learn: 0.0317201	total: 1m 11s	remaining: 1.9s
# 487:	learn: 0.0317201	total: 1m 11s	remaining: 1.75s
# 488:	learn: 0.0317200	total: 1m 11s	remaining: 1.61s
# 489:	learn: 0.0317200	total: 1m 11s	remaining: 1.46s
# 490:	learn: 0.0317200	total: 1m 11s	remaining: 1.31s
# 491:	learn: 0.0317200	total: 1m 11s	remaining: 1.17s
# 492:	learn: 0.0317200	total: 1m 11s	remaining: 1.02s
# 493:	learn: 0.0317200	total: 1m 12s	remaining: 876ms
# 494:	learn: 0.0317200	total: 1m 12s	remaining: 730ms
# 495:	learn: 0.0317200	total: 1m 12s	remaining: 584ms
# 496:	learn: 0.0317200	total: 1m 12s	remaining: 438ms
# 497:	learn: 0.0317199	total: 1m 12s	remaining: 292ms
# 498:	learn: 0.0317199	total: 1m 12s	remaining: 146ms
# 499:	learn: 0.0317191	total: 1m 12s	remaining: 0us

# %%
predicts = []
for i in range(len(models)):
    predicts.append(models[i].predict_proba(test.drop(columns=['ID X PCODE']))[:, 1])

# %%
test['target'] = np.mean(predicts, axis=0)

# %%
true_values = []
for v in test_.values:
    binary = v[8:]
    index = [k for k, i in enumerate(binary) if i == 1]
    for k in test_.columns[8:][index]:
        true_values.append(v[0] + ' X ' + k)

# %%
test = test[['ID X PCODE', 'target']]
test.columns = ['ID X PCODE', 'Label']

# %%
for v in true_values:
    test = test.append({'ID X PCODE':v,'Label':1.0}, ignore_index=True)

# %%
test.reset_index(drop=True, inplace=True)
test.to_csv('submission11.csv', index=False)

# %% [markdown]
# OK
